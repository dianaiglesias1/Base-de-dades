# %% [markdown]
# ## S13 T01: Bases de dades relacionals

# %% [markdown]
# ### Exercici 1
#
# Crea una base relacional d’exemple utilitzant un document de text o a mà. Dissenya-la perquè contingui les següents taules, i estableix les relacions que consideris necessàries entre elles.
#
# Defineix les propietats de les relacions (1:1, 1:n, n:n), i crea algunes de les variables que podrien contenir.

# %% [markdown]
# Relations:
#
# - 1:N One company has many employees
# - 1:N One company has many customers:
#    - 1:N One customer has many transactions
# - 1:N One company has many outlets
# - 1:N One company has many products
# - 1:N One type of product has many products

# %% [markdown]
# ![Diagram.jpg](attachment:Diagram.jpg)

# %% [markdown]
# ### Exercici 2
#
# Utilitza un programa de creació de diagrames entitat-relació com http://dia-installer.de per crear el diagrama.

# %% [markdown]
# ![Untitled%20Diagram%284%29.jpg](attachment:Untitled%20Diagram%284%29.jpg)

# %% [markdown]
# ### Exercici 3
#
# Utilitza el Workbench de MySQL per crear un model relacional.

# %% [markdown]
# *Using Data Reverse Engineer to draw the diagram.*

# %% [markdown]
# ![Diagram%20WorkBench.png](attachment:Diagram%20WorkBench.png)

# %%
#connecting to MySQL

import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="127.0.0.1",
  user="root",
  password="Boston82")

print(mydb)

# %%
mycursor = mydb.cursor()
mycursor.execute("USE foodINC")

# %%
#select all Employees
mycursor.execute("SELECT * FROM Employees")
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (20, 'Angela', 'Davis', 3456)
# (30, 'bell', 'hooks', 3456)
# (40, 'Rosa', 'Parks', 3456)

# %%
#select some columns
mycursor.execute("SELECT DISTINCT Name, LastName FROM Employees")
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# ('Angela', 'Davis')
# ('bell', 'hooks')
# ('Rosa', 'Parks')

# %%
#order by - Employees from high to low
mycursor.execute("SELECT * FROM Employees ORDER BY EmployeeID DESC;")
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (40, 'Rosa', 'Parks', 3456)
# (30, 'bell', 'hooks', 3456)
# (20, 'Angela', 'Davis', 3456)

# %%
#update a value
mycursor.execute("UPDATE Employees SET Name='Bell' WHERE EmployeeID=30")
mycursor.execute("SELECT * FROM Employees")
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (20, 'Angela', 'Davis', 3456)
# (30, 'Bell', 'hooks', 3456)
# (40, 'Rosa', 'Parks', 3456)
